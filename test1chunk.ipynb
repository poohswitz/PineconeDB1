# %%
import os
from pinecone import Pinecone

custom_metadata = {
    "country": "India",
    "state": "Tamil Nadu",
    "district": "Chennai",
    "region": "Guindy",
    "service_category": "OneStopCentre",
    "service_name": "OneStopCentreNo1",
    "source_file": "myfile.pdf"
}

from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("documents/onestopcenter.pdf")
pages = loader.load_and_split()

#attach metadata to each page
for p in pages:
    p.metadata.update(custom_metadata)

#Chunk
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=50)
chunks = splitter.split_documents(pages)








#Adding chunk level metadata
import time, hashlib

ingest_date = time.strftime("%Y-%m-%d")
for i, c in enumerate(chunks):
    h = hashlib.sha1(c.page_content[:100].encode()).hexdigest()[:12]
    c.metadata["chunk_id"] = f"myfile_chunk_{i}_{h}"
    c.metadata["ingest_date"] = ingest_date

#Upsert to Pinecone
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
import pinecone

pc = Pinecone(api_key=os.environ["PINECONE_API_KEY"])

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectorstore = PineconeVectorStore.from_documents(
    chunks,
    embedding=embeddings,
    index_name="pinecone-chatbot"
)


for i, chunk in enumerate(chunks):
    print("=" * 80)
    print(f"CHUNK {i}")
    print("- Text:")
    print(chunk.page_content)
    print("- Metadata:")
    print(chunk.metadata)
    print("=" * 80)


print("Done!")
# Out:
# ================================================================================
# CHUNK 0
# - Text:
# What  is  a  One  Stop  Centre?  One  Stop  Centres  (OSCs)  are  intended  to  support  women  affected  by  violence,  in  private
# and
#
# public
#
# spaces,
#
# within
#
# the
#
# family,
#
# community
#
# and
#
# at
#
# the
#
# workplace.
#
# Women
#
# facing
#
# physical,
#
# sexual,
#
# emotional,
#
# psychological
#
# and
#
# economic
#
# abuse,
#
# irrespective
#
# of
#
# age,
#
# class,
#
# caste,
#
# education
#
# status,
#
# marital
#
# status,
#
# race
#
# and
#
# culture
#
# will
#
# be
#
# facilitated
#
# with
#
# support
#
# and
#
# redressal.
#
# It
#
# is
#
# integrated
#
# with
#
# women
#
# Help
#
# line
#
# number
#
# 181
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk_0_c056e697e332', 'ingest_date': '2025-12-09', 'text': 'What  is  a  One  Stop  Centre?  One  Stop  Centres  (OSCs)  are  intended  to  support  women  affected  by  violence,  in  private  \nand\n \npublic\n \nspaces,\n \nwithin\n \nthe\n \nfamily,\n \ncommunity\n \nand\n \nat\n \nthe\n \nworkplace.\n \nWomen\n \nfacing\n \nphysical,\n \nsexual,\n \nemotional,\n \npsychological\n \nand\n \neconomic\n \nabuse,\n \nirrespective\n \nof\n \nage,\n \nclass,\n \ncaste,\n \neducation\n \nstatus,\n \nmarital\n \nstatus,\n \nrace\n \nand\n \nculture\n \nwill\n \nbe\n \nfacilitated\n \nwith\n \nsupport\n \nand\n \nredressal.\n \nIt\n \nis\n \nintegrated\n \nwith\n \nwomen\n \nHelp\n \nline\n \nnumber\n \n181'}
# ================================================================================
# ================================================================================
# CHUNK 1
# - Text:
# with
#
# women
#
# Help
#
# line
#
# number
#
# 181
#   What  are  the  services  delivered  in  the  OSC?   Emergency  Response  and  Rescue  Services  Medical  assistance  Assistance  to  women  in  lodging  FIR/  NCR/DIR  Psycho-social  support/  counselling  Legal  aid  and  counselling  Shelter  Video  Conferencing  Facility
# 1  Ariyalur  OSC,  Opposite  to  Siddha  ward,  Govt  Head  Quarters  Hosptals  campus,  Ariyalur
# -621704
#
# A.Meenakshi
#
# 8098007634
#
# oscariyalur@gmail.com
#
# 2  Chengalpet  (Tambaram)  Government  Services  Home,  No.  8,  Judge  Colony,  Home  Road,
# Tambaram
#
# Sanitorium
#
# Chennai
#
# –
#
# 47
#
# Anushiya
#
# Remcy
#
# Mabel
#
# 9941937370
#
# osctnchn@gmail.com
#
# 3  Chennai  A  Peripheral  Hospital,  Tondairpet  Chennai  Sowparnikha  8428719559
# oscnorthchennai@gmail.com
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk
gmail.com'}
# ================================================================================
# ================================================================================
# CHUNK 3
# - Text:
# 8754650535
#
# oscdindigul@gmail.com
#
# 9  Erode  OSC,  Govt  Erode  Medical  college  &  Hospittal,  Sanitorium,  Perundurai,  Erode.
# D.Subhashini
#
# 9361492558
#
# oscerode@gmail.com
#
# 10  Kancheepuram  Government  Head  Head  Quarters  Hospital,  TB  block,  Old  railway  road,
# Kanchipuram631501
#
# Naveen
#
# (Incharge)
#
# 9444008822
#
# osckanchipuram@gmail.com
#
# TN
#
# OSCs
#
# Details
#
# S.No
#
# Name
#
# of
#
# the
#
# district
#
# Address
#
# Centre
#
# Admin
#
# Contact
#
# Number
#
# Email
#
# address
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk_3_e0d956098972', 'ingest_date': '2025-12-09', 'text': '8754650535\n \noscdindigul@gmail.com\n \n9  Erode  OSC,  Govt  Erode  Medical  college  &  Hospittal,  Sanitorium,  Perundurai,  Erode.  \nD.Subhashini\n \n9361492558\n \noscerode@gmail.com\n \n10  Kancheepuram  Government  Head  Head  Quarters  Hospital,  TB  block,  Old  railway  road,  \nKanchipuram631501\n \nNaveen\n \n(Incharge)\n \n9444008822\n \nosckanchipuram@gmail.com\n \nTN\n \nOSCs\n \nDetails\n \nS.No\n \nName\n \nof\n \nthe\n \ndistrict\n \nAddress\n \nCentre\n \nAdmin\n \nContact\n \nNumber\n \nEmail\n \naddress'}
# ================================================================================
# ================================================================================
# CHUNK 4
# - Text:
# 11  Kanyakumari  OSC,  Govt  Medical  College  &  Hospital  campus,  Asaaripallam,  Kanniyakumari  -
# 629201
#
# P.D.Sherin
#
# Malar
#
# 9715282667
#
# osckanniyakumari@gmail.com
#
# 12  Karur  OSC,  Old  Medical  College,  Church  Corner,  Karur-609001  Elavarasi  (incharge)
# 6380234617
#
# osctnkarur@gmail.com
#
# 13  Krishnagiri  OSC,  Boolupalli  village,  Govt  Medical  college,  Husur  Highway,  Krishnagiri
# Sarvakala
#
# 9600695643
#
# osckrishnagiri@gmail.com
#
# 14  Madurai  Government  Hospital,  Balarangapuram,  Madurai  P.Premalatha  9486229149
# maduraiosc@gmail.com
#
# 15
#
# Nagapattinam
#
# OSC,
#
# District
#
# Head
#
# Quarters
#
# Hospital,
#
# Nagapattinam
#
# S.Elavarasi
#
# 9578573747
#
# oscnagapattinam@gmail.com
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk_4_2006cf7906df', 'ingest_date': '2025-12-09', 'text': '11  Kanyakumari  OSC,  Govt  Medical  College  &  Hospital  campus,  Asaaripallam,  Kanniyakumari  -  \n629201\n \nP.D.Sherin\n \nMalar\n \n9715282667\n \nosckanniyakumari@gmail.com\n \n12  Karur  OSC,  Old  Medical  College,  Church  Corner,  Karur-609001  Elavarasi  (incharge)  \n6380234617\n \nosctnkarur@gmail.com\n \n13  Krishnagiri  OSC,  Boolupalli  village,  Govt  Medical  college,  Husur  Highway,  Krishnagiri  \nSarvakala\n \n9600695643\n \nosckrishnagiri@gmail.com\n \n14  Madurai  Government  Hospital,  Balarangapuram,  Madurai  P.Premalatha  9486229149  \nmaduraiosc@gmail.com\n \n15\n \nNagapattinam\n \nOSC,\n \nDistrict\n \nHead\n \nQuarters\n \nHospital,\n \nNagapattinam\n \nS.Elavarasi\n \n9578573747\n \noscnagapattinam@gmail.com'}
# ================================================================================
# ================================================================================
# CHUNK 5
# - Text:
# 9578573747
#
# oscnagapattinam@gmail.com
#
# 16  Namakkal  OSC,  Govt  Medical  College  &  Hospital  campus,  Near  Pazhaniyappa  ward,
# Namakkal
#
# -
#
# 637001
#
# S.Vidhya
#
# 9655652896
#
# osctnnamakkal@gmail.com
#
# 17  Nilgris  OSC,  Govt  Medical  College  &  Hospital,  Jail  Hill  road,  Ooty  -  604001  Helen
# Christeenal
#
# 9943040474
#
# oscooty181@gmail.com
#
# 18  Perambalur  OSC,  Govr  Head  Head  Quarters  Hospital  Campus,  Duraiyur  road,
# Perambalur621212
#
# T.
#
# Geetha
#
# 6380469886
#
# oscperambalur@gmail.com
#
# 19  Pudhukottai  OSC,  Old  GH  campus,  West  main  street,  Pudukkottai  -  622001  S.Nirmalarani
# 9894891308
#
# oscpdk19@gmail.com
#
# 20  Ramanathapuram  OSC,  Government  Medical  College,  Hospital  campus,  Ramanathapuram  -
# 623501
#
# S.Mohana
#
# Priya
#
# 8754261057
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk_5_e592cff2193b', 'ingest_date': '2025-12-09', 'text': '9578573747\n \noscnagapattinam@gmail.com\n \n16  Namakkal  OSC,  Govt  Medical  College  &  Hospital  campus,  Near  Pazhaniyappa  ward,  \nNamakkal\n \n-\n \n637001\n \nS.Vidhya\n \n9655652896\n \nosctnnamakkal@gmail.com\n \n17  Nilgris  OSC,  Govt  Medical  College  &  Hospital,  Jail  Hill  road,  Ooty  -  604001  Helen  \nChristeenal\n \n9943040474\n \noscooty181@gmail.com\n \n18  Perambalur  OSC,  Govr  Head  Head  Quarters  Hospital  Campus,  Duraiyur  road,  \nPerambalur621212\n \nT.\n \nGeetha\n \n6380469886\n \noscperambalur@gmail.com\n \n19  Pudhukottai  OSC,  Old  GH  campus,  West  main  street,  Pudukkottai  -  622001  S.Nirmalarani  \n9894891308\n \noscpdk19@gmail.com\n \n20  Ramanathapuram  OSC,  Government  Medical  College,  Hospital  campus,  Ramanathapuram  -  \n623501\n \nS.Mohana\n \nPriya\n \n8754261057'}
# ================================================================================
# ================================================================================
# CHUNK 6
# - Text:
# 623501
#
# S.Mohana
#
# Priya
#
# 8754261057
#
# ramanathapuramosc@gmail.com
#
# 21  Salem  OSC,  Government  Mohan  Kumarmangalam  Medical  College,  Hospital,  ART  Centre
# near,
#
# Salem-636001
#
# K.PeriyarSelvi
#
# 9677918795
#
# osctnsalem@gmail.com
#
# 22  Sivagangai  OSC,  Government  Medical  College,  Hospital  campus,  Sivagangai-630561
# Suganya
#
# 7639644830
#
# osc.sivagangai@gmail.com
#
# S.No
#
# Name
#
# of
#
# the
#
# district
#
# Address
#
# Centre
#
# Admin
#
# Contact
#
# Number
#
# Email
#
# address
#
# 23  Thanjavur  OSC,  Govt  Raja  Mirasdar  Hospital  Campus,  Old  Bus  stand,  ThanjavurVimala
# 6381139108
#
# oscthanjavurdistrict01@gmail.com
#
# 24  Theni  OSC,  Government  Medical  College,  Hospital  campus,  K.  Villakku,  Theni  B
# Murugeshwari
#
# 6383878946
#
# osctheni2019@gmail.com
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk
# ================================================================================
# ================================================================================
# CHUNK 9
# - Text:
# 8508757670
#
# velloreosc@gmail.com
#
# 33  Villupuram  OSC,  Govt  Medical  College  &  Hospital,  Mundiyampakkam,
# VillupuramA.Padmavathi
#
# 7871604171
#
# oscvillupuram@gmail.com
#
# 34  Virudhunagar  Virudhunagar  Govt  Medical  College  &  Hospital  Campus,  Ramamoorthy  road,
# Virudhunagar
#
# -
#
# 62600
#
# Rachel
#
# 9994605844
#
# oscentrevnr@gmail.com
#
# 35  Tenkasi  No.  15/150  D2/8,  Indira  nagar,  Nannagaram,  Tenkasi  Jayarani  8754804997
# osctenkasi@gmail.com
#
# 36  Ranipet  Ranipet  Collectorate,  Ranipet  District  Malar  9655874566  oscranipet@gmail.com
# 37  Thiruppathur  Government  Hospital  Campus,  Thirupathur  district  -635  602  Santhi
# 9159604087
#
# osctpt2022@gmail.com
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk_9_ed524353b733', 'ingest_date': '2025-12-09', 'text': '8508757670\n \nvelloreosc@gmail.com\n \n33  Villupuram  OSC,  Govt  Medical  College  &  Hospital,  Mundiyampakkam,  \nVillupuramA.Padmavathi\n \n7871604171\n \noscvillupuram@gmail.com\n \n34  Virudhunagar  Virudhunagar  Govt  Medical  College  &  Hospital  Campus,  Ramamoorthy  road,  \nVirudhunagar\n \n-\n \n62600\n \nRachel\n \n9994605844\n \noscentrevnr@gmail.com\n \n35  Tenkasi  No.  15/150  D2/8,  Indira  nagar,  Nannagaram,  Tenkasi  Jayarani  8754804997  \nosctenkasi@gmail.com\n \n36  Ranipet  Ranipet  Collectorate,  Ranipet  District  Malar  9655874566  oscranipet@gmail.com  \n37  Thiruppathur  Government  Hospital  Campus,  Thirupathur  district  -635  602  Santhi  \n9159604087\n \nosctpt2022@gmail.com'}
# ================================================================================
# ================================================================================
# CHUNK 10
# - Text:
# 9159604087
#
# osctpt2022@gmail.com
#
# 38  Kallakuritchi  District  Social  Welfare  office,  Collectorate,  Kallakurichi,  Kachirapalayam  main
# road,
#
# Kallakurichi
#
# &
#
# Distict
#
# Manimegalai
#
# 9751011255
#
# osckallakurichi@gmail.com
# - Metadata:
# {'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'ONE STOP CENTRE', 'source': 'documents/onestopcenter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3', 'country': 'India', 'state': 'Tamil Nadu', 'district': 'Chennai', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source_file': 'myfile.pdf', 'chunk_id': 'myfile_chunk_10_8734d3c1e467', 'ingest_date': '2025-12-09', 'text': '9159604087\n \nosctpt2022@gmail.com\n \n38  Kallakuritchi  District  Social  Welfare  office,  Collectorate,  Kallakurichi,  Kachirapalayam  main  \nroad,\n \nKallakurichi\n \n&\n \nDistict\n \nManimegalai\n \n9751011255\n \nosckallakurichi@gmail.com'}
# ================================================================================
# Done!

# %%
from langchain_pinecone import PineconeVectorStore
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectorstore = PineconeVectorStore.from_existing_index(
    index_name="pinecone-chatbot",
    embedding=embeddings
)

retriever = vectorstore.as_retriever(
    search_kwargs={"k": 5}    
)

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama3")
# Out:
# C:\Users\Poorna\AppData\Local\Temp\ipykernel_7620\767351389.py:3: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3")   # or "mistral", "qwen2", etc.

# %%
#Retrieval Only Test1
query = "What are the service given in one stop centre?"

results = vectorstore.similarity_search(query, k=3)

for i, doc in enumerate(results):
    print("="*80)
    print(f"RESULT {i+1}")
    print("- TEXT:\n", doc.page_content[:500], "...")
    print("- METADATA:", doc.metadata)
# Out:
# ================================================================================
# RESULT 1
# - TEXT:
#  What  is  a  One  Stop  Centre?  One  Stop  Centres  (OSCs)  are  intended  to  support  women  affected  by  violence,  in  private
# and
#
# public
#
# spaces,
#
# within
#
# the
#
# family,
#
# community
#
# and
#
# at
#
# the
#
# workplace.
#
# Women
#
# facing
#
# physical,
#
# sexual,
#
# emotional,
#
# psychological
#
# and
#
# economic
#
# abuse,
#
# irrespective
#
# of
#
# age,
#
# class,
#
# caste,
#
# education
#
# status,
#
# marital
#
# status,
#
# race
#
# and
#
# culture
#
# will
#
# be
#
# facilitated
#
# with
#
# support
#
# and
#
# redressal.
#
# It
#
# is ...
# - METADATA: {'creationdate': '', 'creator': 'PyPDF', 'page': 0.0, 'page_label': '1', 'producer': 'Skia/PDF m144 Google Docs Renderer', 'source': 'documents/onestopcenter.pdf', 'title': 'ONE STOP CENTRE', 'total_pages': 3.0}
# ================================================================================
# RESULT 2
# - TEXT:
#  What  is  a  One  Stop  Centre?  One  Stop  Centres  (OSCs)  are  intended  to  support  women  affected  by  violence,  in  private
# and
#
# public
#
# spaces,
#
# within
#
# the
#
# family,
#
# community
#
# and
#
# at
#
# the
#
# workplace.
#
# Women
#
# facing
#
# physical,
#
# sexual,
#
# emotional,
#
# psychological
#
# and
#
# economic
#
# abuse,
#
# irrespective
#
# of
#
# age,
#
# class,
#
# caste,
#
# education
#
# status,
#
# marital
#
# status,
#
# race
#
# and
#
# culture
#
# will
#
# be
#
# facilitated
#
# with
#
# support
#
# and
#
# redressal.
#
# It
#
# is ...
# - METADATA: {'chunk_id': 'myfile_chunk_0_c056e697e332', 'country': 'India', 'creationdate': '', 'creator': 'PyPDF', 'district': 'Chennai', 'ingest_date': '2025-12-09', 'page': 0.0, 'page_label': '1', 'producer': 'Skia/PDF m144 Google Docs Renderer', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source': 'documents/onestopcenter.pdf', 'source_file': 'myfile.pdf', 'state': 'Tamil Nadu', 'title': 'ONE STOP CENTRE', 'total_pages': 3.0}
# ================================================================================
# RESULT 3
# - TEXT:
#  What  is  a  One  Stop  Centre?  One  Stop  Centres  (OSCs)  are  intended  to  support  women  affected  by  violence,  in  private
# and
#
# public
#
# spaces,
#
# within
#
# the
#
# family,
#
# community
#
# and
#
# at
#
# the
#
# workplace.
#
# Women
#
# facing
#
# physical,
#
# sexual,
#
# emotional,
#
# psychological
#
# and
#
# economic
#
# abuse,
#
# irrespective
#
# of
#
# age,
#
# class,
#
# caste,
#
# education
#
# status,
#
# marital
#
# status,
#
# race
#
# and
#
# culture
#
# will
#
# be
#
# facilitated
#
# with
#
# support
#
# and
#
# redressal.
#
# It
#
# is ...
# - METADATA: {'chunk_id': 'myfile_chunk_0_c056e697e332', 'country': 'India', 'creationdate': '', 'creator': 'PyPDF', 'district': 'Chennai', 'ingest_date': '2025-12-09', 'page': 0.0, 'page_label': '1', 'producer': 'Skia/PDF m144 Google Docs Renderer', 'region': 'Guindy', 'service_category': 'OneStopCentre', 'service_name': 'OneStopCentreNo1', 'source': 'documents/onestopcenter.pdf', 'source_file': 'myfile.pdf', 'state': 'Tamil Nadu', 'title': 'ONE STOP CENTRE', 'total_pages': 3.0}
